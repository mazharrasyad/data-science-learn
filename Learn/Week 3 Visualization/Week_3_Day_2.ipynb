# %% [markdown]
# <h2>Tugas Harian 2</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note : warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(x, cos, label='Cosx', color='#FF0000')
ax.plot(x, cos3, label='3 Cosx', linestyle='--', color='#008000')
ax.plot(x, sin, label='Sin(x-90)', linestyle='-.', color='#0000FF')
ax.plot(x, sin2, label='2 Sinx', marker='x', linestyle='', color='#FFFF00')
ax.legend(loc='center')

# %% [markdown]
# Expected Result :
#
# ![image.png](attachment:image.png)
