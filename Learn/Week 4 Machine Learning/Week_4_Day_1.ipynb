# %% [markdown]
# <h1>Quiz 1 : Pemahaman Machine Learning</h1>
#
# Jawab/Kerjakan pertanyaan/perintah di bawah ini dengan bahasa kalian sendiri :
#
# - Apa itu machine learning?
# - Apa itu data feature dan data target
# - Apa Perbedaan Supervised Learning, dan Unsupervised Learning
# - Apa Jenis2 yang ada di dalam Supervised Learning? Jelaskan Perbedaannya!
# - Apa perbedaan Hyperparameter dan Parameter
# - Sebutkan step2 dalam mengapplikasikan algoritma apapun dalam machine learning

# %% [markdown]
# 1. Machine learning adalah komputer yang memiliki kemapuan belajar dari pengalaman terhadap tugas-tugasnya di masa lalu dan mengalami peningkatan kinerja (Tom Mitchell, 1997)
#
# 2. Data feature adalah variable yang memprediksi suatu kejadian atau suatu target, sedangkan data target adalah hasil dari prediksi tersebut.
#
# 3. Supervised learning memiliki label dan outputnya jelas sedangkan unsupervised learning tidak memiliki label dan outputnya tidak jelas.
#
# 4. Supervised learning terbagi menjadi 2 jenis yaitu classification dan regression, perbedaannya terdapat di outputnya yang sedang diprediksi, jikalau classification outputnya berupa label sedangkan regression outputnya berupa quantity yang continues.
#
# 5. Hyperparameter didefinisikan di awal pembuatan objek model dan tidak ada sangkut pautnya dengan model sedangkan parameter pembuatan objek dihasilkan di akhir dan ada sangkut pautnya dengan model.
#
# 6. Berikut step-step dalam mengaplikasikan algoritma dalam machine learning:
# - Pilih model atau algoritma yang akan digunakan
# - Pilih hyperparameter ketika membuat objek model
# - Pisahkan antara data feature dan data target
# - Perintahkan model untuk mempelajari data dengan menggunakan method .fit()
# - Aplikasikan model ke dalam test data dengan menggunakan method .predict() untuk supervised learn atau .transform() dan .predict() untuk unsupervised learning

# %% [markdown]
# <h1>Quiz 2 : Pemahaman Machine Learning</h1>
#
# Pelajarilah secara garis besar suatu model/algoritma machine learning, kemudian applikasikan untuk membuat model bagi data (variable x, y) di bawah ini. kemudian buatlah prediksi terhadap data training dan data baru di interval 20-30.
#
# - Plot data asli, data hasil prediksi terhadap data training, data hasil prediksi terhadap data baru
# - Tunjukan beberapa parameter yang dimiliki model yang telah kalian buat

# %%
import matplotlib.pyplot as plt
import numpy as np

rng = np.random.RandomState(42)
x = 20 * rng.rand(50)
y = x**2 + 2 * x + - 1 + rng.randn(50)

# data yang akan di prediksi
x_new = np.arange(20, 30, 0.5)

fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y)
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.show()

# %%
# 1
from sklearn.tree import DecisionTreeRegressor
# 2
model_tree = DecisionTreeRegressor(max_depth=4, min_samples_split=6, min_samples_leaf=6)
# 3 
x_matriks = x[:, np.newaxis]
# 4
model_tree.fit(x_matriks, y)
# 5
x_test = x_new[:, np.newaxis]
y_test = model_tree.predict(x_test)
y_train = model_tree.predict(x_matriks)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y, label='Data Asli', color='b')
ax.scatter(x, y_train, label='Prediksi terhadap data training', color='y')
ax.plot(x_test, y_test, label='Prediksi terhadap data baru', color='g')
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.legend(bbox_to_anchor=(1.1,1.2))
plt.show()

# %% [markdown]
# Contoh Jawaban Hasil Pembuatan Model dengan Algoritma DecisionTreeRegressor (Jawaban tidak haru sama) :
#
# ![image.png](attachment:image.png)

# %%
from sklearn import tree
clf = DecisionTreeRegressor(max_depth=4, min_samples_split=6, min_samples_leaf=6)
tree.plot_tree(clf.fit(x_matriks, y))
# Out:
# [Text(209.25000000000003, 195.696, 'X[0] <= 12.744\nmse = 15993.388\nsamples = 50\nvalue = 129.087'),
#  Text(139.5, 152.208, 'X[0] <= 8.065\nmse = 3370.867\nsamples = 37\nvalue = 64.087'),
#  Text(83.7, 108.72, 'X[0] <= 4.711\nmse = 424.568\nsamples = 24\nvalue = 25.148'),
#  Text(55.800000000000004, 65.232, 'X[0] <= 2.615\nmse = 72.147\nsamples = 16\nvalue = 12.186'),
#  Text(27.900000000000002, 21.744, 'mse = 9.288\nsamples = 7\nvalue = 3.605'),
#  Text(83.7, 21.744, 'mse = 19.206\nsamples = 9\nvalue = 18.861'),
#  Text(111.60000000000001, 65.232, 'mse = 121.393\nsamples = 8\nvalue = 51.071'),
#  Text(195.3, 108.72, 'X[0] <= 10.715\nmse = 843.286\nsamples = 13\nvalue = 135.974'),
#  Text(167.4, 65.232, 'mse = 251.248\nsamples = 7\nvalue = 112.335'),
#  Text(223.20000000000002, 65.232, 'mse = 121.556\nsamples = 6\nvalue = 163.552'),
#  Text(279.0, 152.208, 'X[0] <= 16.986\nmse = 5668.677\nsamples = 13\nvalue = 314.088'),
# ...

# %% [markdown]
# Contoh Jawaban Parameters (Tidak Harus Sama) :
#
# - Feature Importance : array([1.])
# - n features : 1
#
# Tree Graph :
#
# ![image.png](attachment:image.png)
